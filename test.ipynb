# %%
# sequential
angka = int(input("masukkan angka: "))
hasil = angka * 10
print("hasil perhitungan: ", hasil)
# Out:
# hasil perhitungan:  200

# %%
print("hello teman-teman semuanya")
# Out:
# hello teman-teman semuanya

# %%
list_siswa = ["farhan", "aji", "heri"]
print(list_siswa)
# Out:
# ['farhan', 'aji', 'heri']
