# %%
# latihan 1

nama = "aji"
umur = 34
tinggi = 170
print("nama: " nama)
print("umur: " umur)
print("tinggi: " tinggi)

# %%
# latihan : tipe data
teks = "belajar python"
bil_bulat = 150
bil_desimal = 3.14
is_active = True
print(type(teks))
print(type(bil_bulat))
print(type(bil_desimal))
print(type(is_active))
